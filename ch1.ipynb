# %% [markdown]
# <a href="https://colab.research.google.com/github/bctcaiedu/data_analysis_python/blob/main/ch1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# # **ls 명령어**
#
# Linux/Mac 에서 파일 및 디렉토리 목록을 출력하는 명령어입니다.
#
# **기본 사용법**
#
#
# ```
# ls          # 현재 폴더 목록
# ls /home    # 특정 폴더 목록
# ls *.txt    # 특정 파일만 (와일드카드)
# ```

# %%
# !pwd
# Out:
# /content

# %%
# !cd sample_data

# %%
print('Hello, Google colab!')
result = 1+2+3
print(f'결과: {result}')
# Out:
# Hello, Google colab!

# %%
import pandas as pd
from google.colab import drive

# Google Drive 마운트
drive.mount('/content/drive')

# data.csv 파일 경로 (실제 파일 경로에 맞게 수정해주세요)
# 예: /content/drive/MyDrive/data.csv
# 또는 특정 폴더 안에 있다면: /content/drive/MyDrive/MyFolder/data.csv
file_path = '/content/drive/MyDrive/military_meal_2026_H1.csv'

try:
    # CSV 파일 불러오기
    df = pd.read_csv(file_path)

    # 데이터 확인
    print("데이터 상위 5행:")
    print(df.head())

    print("\n데이터 정보:")
    df.info()

    print("\n결측치 확인:")
    print(df.isnull().sum())

except FileNotFoundError:
    print(f"오류: 파일이 존재하지 않습니다. 경로를 확인해주세요: {file_path}")
except Exception as e:
    print(f"오류 발생: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 데이터 상위 5행:
#            날짜 요일 식사구분  메뉴번호    메뉴명  음식분류  칼로리(kcal)  단백질(g)  지방(g)  탄수화물(g)  \
# 0  2026-01-01  목   조식     1     팥밥    주식        338     5.0   21.4     31.4
# 1  2026-01-01  목   조식     2  삼계탕국물  국/찌개        108     5.4    9.5      5.0
# 2  2026-01-01  목   조식     3  삼겹살구이    주찬        253     8.7   17.2     15.9
# 3  2026-01-01  목   조식     4   상추무침    부찬         59     6.5    5.6      5.0
# 4  2026-01-01  목   조식     5   두부부침    부찬         65    31.4   18.8      5.0
#
#    나트륨(mg)  당류(g)  식이섬유(g)  콜레스테롤(mg)  포화지방(g)  원산지  보관방법 알레르기유발물질      비고
# 0      897   13.2      1.2         72      3.7  호주산  상온보관    우유,계란  신정 특별식
# 1      567    7.2      3.1         88      1.0  국내산  상온보관       우유  신정 특별식
# 2      256    1.1      2.7         17      4.8  국내산  냉장보관  난류,밀,대두  신정 특별식
# 3      697   12.6      3.5         41      5.6  국내산  상온보관     대두,밀  신정 특별식
# 4      617   12.1      5.9          0      7.7  중국산  상온보관       우유  신정 특별식
#
# 데이터 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4344 entries, 0 to 4343
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   날짜         4344 non-null   object
#  1   요일         4344 non-null   object
#  2   식사구분       4344 non-null   object
#  3   메뉴번호       4344 non-null   int64
#  4   메뉴명        4344 non-null   object
#  5   음식분류       4344 non-null   object
#  6   칼로리(kcal)  4344 non-null   int64
#  7   단백질(g)     4344 non-null   float64
#  8   지방(g)      4344 non-null   float64
#  9   탄수화물(g)    4344 non-null   float64
#  10  나트륨(mg)    4344 non-null   int64
#  11  당류(g)      4344 non-null   float64
#  12  식이섬유(g)    4344 non-null   float64
#  13  콜레스테롤(mg)  4344 non-null   int64
#  14  포화지방(g)    4344 non-null   float64
#  15  원산지        4344 non-null   object
#  16  보관방법       4344 non-null   object
#  17  알레르기유발물질   4344 non-null   object
#  18  비고         256 non-null    object
# dtypes: float64(6), int64(4), object(9)
# memory usage: 644.9+ KB
#
# 결측치 확인:
# 날짜              0
# 요일              0
# 식사구분            0
# 메뉴번호            0
# 메뉴명             0
# 음식분류            0
# 칼로리(kcal)       0
# 단백질(g)          0
# 지방(g)           0
# 탄수화물(g)         0
# 나트륨(mg)         0
# 당류(g)           0
# 식이섬유(g)         0
# 콜레스테롤(mg)       0
# 포화지방(g)         0
# 원산지             0
# 보관방법            0
# 알레르기유발물질        0
# 비고           4088
# dtype: int64
